# %% [markdown]
# Files, exceptional handling, logging and memory management Assignment

# %% [markdown]
# Theory Assignment
#
#
# 1. What is the difference between interpreted and compiled languages
#
# ans:
#
#     Compiled languages (e.g., C, C++) are converted into machine code before execution.
#
#     Interpreted languages (e.g., Python) are executed line by line by an interpreter at runtime.
#
#      Python is interpreted.
#
# 2. What is exception handling in Python
#
# ans :
#
#     Exception handling allows programs to respond to errors gracefully using try, except, else, and finally blocks.
#
# 3. What is the purpose of the finally block in exception handling
#
# ans:
#     The finally block always executes whether an exception occurs or not — commonly used for clean-up actions like closing files or releasing resources.
#
# 4. What is logging in Python
#
# ans :
#
#     Logging is a way to record messages about the program’s execution (e.g., info, warnings, errors) using the logging module — helpful for debugging and monitoring.
#
# 5. What is the significance of the __del__ method in Python
#
# ans:
#
#       __del__() is a destructor method called when an object is about to be destroyed (garbage collected). It’s used for clean-up actions like closing connections.
#
# 6. What is the difference between import and from ... import in Python
#
# ans:
#
#     import module → imports the whole module.
#
#     from module import name → imports specific items from the module.
#
# 7. How can you handle multiple exceptions in Python
#
# ans:
#
#    I can handle multiple exceptions by:
#
#     try:
#         ...
#     except (TypeError, ValueError) as e:
#         print(e)
#
#
#     try:
#         ...
#     except TypeError as e:
#         print(e)
#     except ValueError as v:
#       print(v)
#
#
#     Or use multiple except blocks.
#
# 8. What is the purpose of the with statement when handling files in Python
#
# ans:
#
#   The with statement automatically manages resources (like files).
#
#   Example:
#
#     with open('file.txt') as f:
#         data = f.read()
#     # File automatically closed
#
# 9. What is the difference between multithreading and multiprocessing
#
# ans:
#
#     Multithreading →
#         multiple threads share the same memory space (good for I/O-bound tasks).
#
#     Multiprocessing →
#       separate processes with independent memory (good for CPU-bound tasks).
#
# 10. What are the advantages of using logging in a program
#
# ans:
#
#     1. Tracks program flow
#
#     2. Helps diagnose issues
#
#     3. Stores runtime information
#
#     4. Can be configured for file or console output
#
# 11. What is memory management in Python
#
# ans:
#
#       Python uses automatic memory management — it allocates and frees memory using reference counting and garbage collection.
#
# 12. What are the basic steps involved in exception handling in Python
#
# ans:
#
#       1. try block → code that might raise an error
#
#       2. except block → handles the error
#
#       3. else block → runs if no exception
#
#       4. finally block → always executes
#
# 13. Why is memory management important in Python
#
# ans:
#
#     Efficient memory management prevents memory leaks, ensures optimal performance, and allows Python to run large programs smoothly.
#
# 14. What is the role of try and except in exception handling
#
# ans:
#
#       try: defines code that might raise an exception.
#
#       except: defines how to handle specific exceptions.
#
# 15. How does Python's garbage collection system work
#
# ans:
#
#     Uses reference counting and cyclic garbage collector to reclaim memory occupied by unreferenced objects.
#
# 16. What is the purpose of the else block in exception handling
#
# ans:
#
#     The else block executes only if no exceptions occur in the try block.
#
# 17. What are the common logging levels in Python
#
# ans:
#
#     1. DEBUG – detailed info
#
#     2. INFO – general events
#
#     3. WARNING – possible issues
#
#     4. ERROR – serious problem
#
#     5. CRITICAL – severe error
#
# 18. What is the difference between os.fork() and multiprocessing in Python
#
# ans:
#
#     os.fork() → Unix-only, creates a new process by duplicating the current one.
#
#     multiprocessing → cross-platform library for creating and managing processes easily.
#
# 19. What is the importance of closing a file in Python
#
# ans:
#
#     Closing a file frees system resources and ensures data is written properly to disk.
#
# 20. What is the difference between file.read() and file.readline() in Python
#
# ans:
#
#     read() → reads the entire file or a specified number of bytes.
#
#     readline() → reads one line at a time.
#
# 21. What is the logging module in Python used for
#
# ans:
#
#     The logging module provides a flexible framework for emitting log messages from Python programs.
#
# 22. What is the os module in Python used for in file handling
#
# ans:
#
#     The os module allows interaction with the operating system, including file and directory operations (os.rename, os.remove, os.path etc.).
#
# 23. What are the challenges associated with memory management in Python
#
# ans:
#
#     1. Circular references
#
#     2. Memory leaks from long-lived objects
#
#     3. Large data structures consuming excessive memory
#
# 24.  How do you raise an exception manually in Python
#
# ans:
#     using ValueError() manually exception will occure:
#
#       raise ValueError("Invalid input")
#
# 25. Why is it important to use multithreading in certain applications
#
# ans:
#
#       Multithreading is important for I/O-bound tasks (like network requests) — it increases efficiency by allowing concurrent execution without waiting for slow operations.

# %% [markdown]
# Precticle Assignment

# %%
# 1. How can you open a file for writing in Python and write a string to it

line = "hello world \n I am vishakha"

with open("test.txt","w") as f:
  f.write(line)

# %%
# 2. Write a Python program to read the contents of a file and print each line

with open("test.txt","r") as f:
  print(f.read())
# Out:
# hello world
#  I am vishakha

# %%
#3. How would you handle a case where the file doesn't exist while trying to open it for reading

try:
  file_test = open("test1.txt","r")
except FileNotFoundError as e:
  print("file not exists error",e)
else:
  print(file_test.read())
  file_test.close()
# Out:
# file not exists error [Errno 2] No such file or directory: 'test1.txt'

# %%
# 4. Write a Python script that reads from one file and writes its content to another file


with open("test.txt","r") as src , open("test_copy.txt","w") as dest:
  for i in src:
    dest.write(i)

# %%
# 5. How would you catch and handle division by zero error in Python

num1 = int(input("Enter Divident :"))
num2 = int(input("Enter Divisor :"))

try:
  ans = num1/num2
except ZeroDivisionError as e:
  print("Zero division error Occur")
except Exception as e:
  print("Exception Occure :",e)
else:
  print("Result:" ,ans)
# Out:
# Enter Divident :4
# Enter Divisor :0
# Zero division error Occur

# %%
#6. Write a Python program that logs an error message to a log file when a division by zero exception occursF

import logging

for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    filename="log_file.log",
    filemode="a",
    format="%(asctime)s - %(levelname)s - %(message)s",
    level=logging.INFO
)

num1 = int(input("Enter Dividend: "))
num2 = int(input("Enter Divisor: "))

try:
    ans = num1 / num2
except ZeroDivisionError:
    logging.error("ZeroDivisionError occurred — attempted to divide by zero.")
    print("Error: Cannot divide by zero.")
except Exception as e:
    logging.error(f"Unexpected exception occurred: {e}")
    print("An unexpected error occurred:", e)
else:
    print("Result:", ans)
    logging.info(f"Division successful: {num1} / {num2} = {ans}")
# Out:
# Enter Dividend: 4
# Enter Divisor: 0
# Error: Cannot divide by zero.

# %%
#7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module


import logging

for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    filename="app.log",
    filemode="a",
    format="%(asctime)s - %(levelname)s - %(message)s",
    level=logging.INFO
)

logging.debug("This is a DEBUG message (useful for developers).")
logging.info("This is an INFO message (general information).")
logging.warning("This is a WARNING message (something unexpected, but still running).")
logging.error("This is an ERROR message (something went wrong).")
logging.critical("This is a CRITICAL message (severe error, may crash program).")

# %%
#8 Write a program to handle a file opening error using exception handling

try:
    with open("test1.txt", "r") as file_test:
        print(file_test.read())
except FileNotFoundError as e:
    print("File not found error:", e)
except PermissionError as e:
    print("Permission denied:", e)
except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# File not found error: [Errno 2] No such file or directory: 'test1.txt'

# %%
#9. How can you read a file line by line and store its content in a list in Python

with open("test.txt","r") as f:
  lines = [line.strip() for line in f.readlines()]

print(lines)
# Out:
# ['hello world', 'I am vishakha', 'I am 23 year old', 'I am from bilimora']

# %%
#10. How can you append data to an existing file in Python

with open("test.txt", "a") as append_data:
  append_data.write("\nI am 23 year old\n I am from bilimora")

# %%
#11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist

dic = {"name":"vishakha","age":23,"city":"bilimora"}

try:
  print(dic["state"])
except KeyError as k:
  print(f"Key {k} Does not exist in dictionary")
# Out:
# Key 'state' Does not exist in dictionary

# %%
#12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions

try:
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))

    result = num1 / num2

    sample_dict = {"name": "Vishakha", "age": 23}
    print(sample_dict["city"])

except ZeroDivisionError:
    print("Error: Cannot divide by zero.")

except ValueError:
    print("Error: Invalid input. Please enter an integer.")

except KeyError as e:
    print(f"Error: Key '{e}' not found in the dictionary.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")

else:
    print(f"Division result: {result}")
# Out:
# Enter a number: 4
# Enter another number: 5
# Error: Key ''city'' not found in the dictionary.

# %%
#13.How would you check if a file exists before attempting to read it in Python

import os

file_path ="test_demo.txt"

if(os.path.exists(file_path)):
  with open("test.txt","r") as f:
    print(f.read())
else:
  print("file not exists")
# Out:
# file not exists

# %%
# 14. Write a program that uses the logging module to log both informational and error messages


import logging

for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    filename="log_file.log",
    filemode="a",
    format="%(asctime)s - %(levelname)s - %(message)s",
    level=logging.INFO
)

try:
    logging.info("Program started successfully.")

    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2

    logging.info(f"Division successful: {num1} / {num2} = {result}")
    print("Result:", result)

except ZeroDivisionError:
    logging.error("Division by zero attempted.")
    print("Error: Cannot divide by zero.")

except ValueError as e:
    logging.error(f"Invalid input: {e}")
    print("Error: Please enter a valid integer.")

except Exception as e:
    logging.error(f"Unexpected error: {e}")
    print("An unexpected error occurred.")
# Out:
# Enter a number: 4
# Enter another number: 3
# Result: 1.3333333333333333

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty
file = open("test_demo.txt","w")

try:
  with open("test_demo.txt","r") as f:
    content = f.read()
    if content:
      print(f"File Content : {content}")
    else:
      print("File is empty")
except FileNotFoundError as e:
  print("file not found")
except Exception as e:
  print(f"Exception Occured : {e}")
# Out:
# File is empty

# %%
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program
# !pip install memory-profiler

from memory_profiler import memory_usage

def create_list():
    return [i for i in range(100)]

mem_usage = memory_usage((create_list,))
print("Memory usage (MiB):", mem_usage)
# Out:
# ...
# Memory usage (MiB): [227.66015625, 227.66015625, 227.66015625]

# %%
#17. Write a Python program to create and write a list of numbers to a file, one number per line

lst = [1,2,3,4,5,6,7]

with open("file_list.txt","w") as f:
  for i in lst:
    f.write(str(i)+"\n")



with open("file_list.txt","r") as f:
  print(f.read())
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
#18.How would you implement a basic logging setup that logs to a file with rotation after 1MB
import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger("log_file")
logger.setLevel(logging.INFO)

handler = RotatingFileHandler(
    "log_file.log",
    maxBytes=1*1024*1024,
    backupCount=3
)

formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)

logger.addHandler(handler)

logger.info("Program started.")
for i in range(10000):
    logger.info(f"Logging message {i}")
logger.error("This is an error message.")

# %%
# 19. Write a program that handles both IndexError and KeyError using a try-except block


try:
  lst = [1,2,3,4,5,6]

  print(lst[10])

  dic = {"name":"vishakha","age":23,"city":"bilimora"}
  print(dic["state"])

except KeyError as k:
  print(f"Key {k} Does not exist in dictionary")

except IndexError as i:
  print(f"Index Error : {i}")

except Exception as e:
  print(f"Unexpected occure : {e}")
# Out:
# Index Error : list index out of range

# %%
#20.How would you open a file and read its contents using a context manager in Python

file_path = "test.txt"

with open(file_path, "r") as f:
    content = f.read()

print(content)
# Out:
# hello world
#  I am vishakha
# I am 23 year old
#  I am from bilimora

# %%
# 21 Write a Python program that reads a file and prints the number of occurrences of a specific word
from collections import Counter


file_path = "test.txt"

with open(file_path, "r") as f:
     word_count = f.read().split()


print(Counter(word_count))
# Out:
# Counter({'I': 3, 'am': 3, 'hello': 2, 'world': 1, 'vishakha': 1, '23': 1, 'year': 1, 'old': 1, 'from': 1, 'bilimora': 1})

# %%
#22. How can you check if a file is empty before attempting to read its contents.

import os

try:
  if os.path.exists("test_demo.txt") and os.path.getsize("test_demo.txt") > 0:
    with open("test.txt", "r") as f:
        print(f.read())
  else:
    print("The file is empty or does not exist.")

except FileNotFoundError as e:
  print("file not exists")
# Out:
# The file is empty or does not exist.

# %%
#23. Write a Python program that writes to a log file when an error occurs during file handling.
import logging

for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    filename="app.log",
    filemode="a",
    format="%(asctime)s - %(levelname)s - %(message)s",
    level=logging.INFO
)

file_path = "test_demo1.txt"

try:
  with open(file_path,"r") as f:
    content = f.read()
    if content:
      print(f"File Content : {content}")
      logging.info("file successfully read")
    else:
      print("File is empty")
      logging.info("file is empty")
except FileNotFoundError as e:
  print("file not found")
  logging.error(f"File not Found {file_path}")
except Exception as e:
  print(f"Exception Occured : {e}")
  logging.error(f"Exception Occured : {e}")
# Out:
# file not found
